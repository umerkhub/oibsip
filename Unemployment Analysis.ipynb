# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
unemployment_df = pd.read_csv('Unemployment_Rate_upto_11_2020.csv')

# %%
unemployment_df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# 4             12988845                                     36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# ...

# %%
unemployment_df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Region.1', 'longitude', 'latitude'],
#       dtype='object')

# %%
unemployment_df.shape
# Out:
# (267, 9)

# %%
unemployment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                  267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %%
unemployment_df = unemployment_df.rename(columns={'Region':'State',
                            ' Estimated Unemployment Rate (%)':'EUR',
                            ' Estimated Employed':'EE',
                            ' Estimated Labour Participation Rate (%)':'ELPR',
                            'Region.1':'Regions'})

# %%
unemployment_df.describe()
# Out:
#               EUR            EE        ELPR   longitude    latitude
# count  267.000000  2.670000e+02  267.000000  267.000000  267.000000
# mean    12.236929  1.396211e+07   41.681573   22.826048   80.532425
# std     10.803283  1.336632e+07    7.845419    6.270731    5.831738
# min      0.500000  1.175420e+05   16.770000   10.850500   71.192400
# 25%      4.845000  2.838930e+06   37.265000   18.112400   76.085600
# 50%      9.650000  9.732417e+06   40.390000   23.610200   79.019300
# 75%     16.755000  2.187869e+07   44.055000   27.278400   85.279900
# max     75.850000  5.943376e+07   69.690000   33.778200   92.937600

# %%
unemployment_df['Regions'].unique()
# Out:
# array(['South', 'Northeast', 'East', 'West', 'North'], dtype=object)

# %%
unemployment_df.Regions.value_counts()
# Out:
# North        79
# South        60
# West         50
# East         40
# Northeast    38
# Name: Regions, dtype: int64

# %%
unemployment_df['State'].unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Meghalaya', 'Odisha', 'Puducherry', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal'], dtype=object)

# %%
unemployment_df.State.value_counts()
# Out:
# Andhra Pradesh      10
# Assam               10
# Uttarakhand         10
# Uttar Pradesh       10
# Tripura             10
# Telangana           10
# Tamil Nadu          10
# Rajasthan           10
# Punjab              10
# Puducherry          10
# Odisha              10
# Meghalaya           10
# Maharashtra         10
# Madhya Pradesh      10
# Kerala              10
# Karnataka           10
# Jharkhand           10
# Himachal Pradesh    10
# Haryana             10
# Gujarat             10
# Goa                 10
# Delhi               10
# Chhattisgarh        10
# Bihar               10
# West Bengal         10
# Jammu & Kashmir      9
# Sikkim               8
# Name: State, dtype: int64

# %%
plt.figure(figsize=(10,7))

plt.title('Correlation Diagram')

sns.heatmap(unemployment_df.corr(),annot=True)
# Out:
# <AxesSubplot:title={'center':'Correlation Diagram'}>

# %%
sns.pairplot(unemployment_df,hue='Regions')

# %%
plt.figure(figsize=(10,7))


plt.title('Unemployment Rate')


sns.histplot(x='EUR',hue='Regions',data=unemployment_df)
# Out:
# <AxesSubplot:title={'center':'Unemployment Rate'}, xlabel='EUR', ylabel='Count'>
